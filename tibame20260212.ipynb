# %% [markdown]
# <a href="https://colab.research.google.com/github/lichinyuan/tibame/blob/main/tibame20260212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
print(a)
# Out:
# 3

# %% [markdown]
# 1.正統python 是.py做結尾
#
# 2.python工具叫做(Jupyter notebook):.ipynb結尾
#
# 3.colab:線上jupyter notebook環境
#
# 4.jupyter notebook的記事本:Markdown語法
#
# 5.還支援Latex Math，以$符號開始，$符號作結尾
#
# $ area = \frac {1}{2} \pi r^2 $
#
#
#
# ```
# 完全平方日: 20241001 = 4499 * 4499
#
# 題目:要從20241001往後數十個完全平方日印出來
#
#
# #可以先將20241001往後日期可以順利平方
# #盡然是4499以後，那我應該是從4499之後平方
# #他能對應到日期的格式，那就是平方
# #看到題目不急著先寫程式，但是要先思考用中文如何呈現，再把它翻成程式，再考慮效能問題(優化)
# #演算法是想法
#
# 完全平方日：20241001 = 4499 × 4499
#
# 題目：
# 要從 20241001 往後數十個完全平方日，印出來。
#
# 想法：
#
# 20241001 開根號是否為整數？
# 20241002...
# 20241003...
#
# 4499 × 4499 是否是一個日期
# 4500 × 4500...
# 4501 × 4501...
#
# 下一個 20720704 = 4552 × 4552
#
# 想法1：
# 48年 × 365 = 17520次
#
# 想法2：
# 4552 − 4499 = 103次
#
# 選擇想法2：速度上快了百倍
#
#
# ```

# %% [markdown]
# ```
# 想法2. 實作
#
# 1. 不限次數的迴圈往下
# 2. 數字 ^ 2
# 3. 檢查這日期是否合理
#
# 年: >= 1
# 月: 12~1
# 日:
# 1. 他每個月不一樣
# 2. 閏年
#
# ```

# %%
def is_leap_year(year):
    if (year%4 == 0 and year%100 != 0) or (year%100 == 0 and year%400 == 0) :
        return True
    else:
        return False
# Out:
# 5

# %%
i = 4499
total = 0
year = 2100
dd2 = 0

if (year%4 == 0 and year%100 != 0) or (year%100 == 0 and year%400 == 0) :
    dd2 = "29"
else:
    dd2 = "28"

date = [
    {"01":"31"},
    {"02":dd2},
    {"03":"31"},
    {"04":"30"},
    {"05":"31"},
    {"06":"30"},
    {"07":"31"},
    {"08":"31"},
    {"09":"30"},
    {"10":"31"},
    {"11":"30"},
    {"12":"31"}
]

while True:
    total = i * i

    if total[-3:-5] == date[int(total[-3:-5])].

    i += 1
# Out:
# 平年
